# %%
# !git clone https://github.com/nmilleson/csp-cst627-week2
# Out:
# Cloning into 'csp-cst627-week2'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 13 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 11.47 KiB | 11.47 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# Run training pipeline
# %run csp-cst627-week2/pipeline.py
# Out:
# Epoch 1: train_loss=2.0113, val_loss=1.9126, val_token_acc=0.2637, val_sequence_acc=0.0000
# Epoch 2: train_loss=1.8180, val_loss=1.7284, val_token_acc=0.3386, val_sequence_acc=0.0000
# Epoch 3: train_loss=1.6193, val_loss=1.5472, val_token_acc=0.4160, val_sequence_acc=0.0000
# Epoch 4: train_loss=1.4522, val_loss=1.3677, val_token_acc=0.4894, val_sequence_acc=0.0000
# Epoch 5: train_loss=1.2449, val_loss=1.1437, val_token_acc=0.5713, val_sequence_acc=0.0110
# Epoch 6: train_loss=1.0750, val_loss=1.0430, val_token_acc=0.6041, val_sequence_acc=0.0100
# Epoch 7: train_loss=0.9675, val_loss=0.9314, val_token_acc=0.6490, val_sequence_acc=0.0130
# Epoch 8: train_loss=0.8675, val_loss=0.8353, val_token_acc=0.6801, val_sequence_acc=0.0270
# Epoch 9: train_loss=0.7870, val_loss=0.7703, val_token_acc=0.7027, val_sequence_acc=0.0420
# Epoch 10: train_loss=0.7363, val_loss=0.7395, val_token_acc=0.7099, val_sequence_acc=0.0600
# ...

# %%
# Run analysis scripts
# %run csp-cst627-week2/modelAnalysis.py
# Out:
# Input: tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0')
# RoPE Output: tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0')
# Sinusoidal Output: tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0')
#
# RoPE Lens Predictions: [tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0'), tensor([[6, 6, 6, 6, 6, 6, 6, 6]], device='cuda:0'), tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0')]
# Sinusoidal Lens Predictions: [tensor([[7, 7, 2, 2, 2, 7, 7, 7]], device='cuda:0'), tensor([[4, 1, 1, 4, 4, 4, 4, 4]], device='cuda:0'), tensor([[1, 1, 1, 1, 1, 1, 1, 1]], device='cuda:0')]
#
# Input: tensor([[1, 2, 3, 4, 5, 6, 7, 0]], device='cuda:0')
# RoPE Output: tensor([[0, 1, 2, 3, 4, 5, 6, 7]], device='cuda:0')
# Sinusoidal Output: tensor([[0, 1, 2, 3, 4, 5, 6, 7]], device='cuda:0')
#
# RoPE Lens Predictions: [tensor([[1, 7, 5, 1, 1, 5, 5, 1]], device='cuda:0'), tensor([[0, 7, 7, 0, 0, 7, 7, 6]], device='cuda:0'), tensor([[0, 1, 2, 3, 4, 5, 6, 7]], device='cuda:0')]
# ...

# %%
# !cd csp-cst627-week2/
# !git add .
# !git commit -m 'assignment update'
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
